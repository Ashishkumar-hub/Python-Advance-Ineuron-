# %% [markdown]
# **Ineuron Python Advance Assignment 6**

# %% [markdown]
# Q1. Explain why selenium is important in web scraping.
#
# Answer: Selenium is a Python library and tool used for automating web browsers to do a number of tasks. One of such is web-scraping to extract useful data and information that may be otherwise unavailable. I prefer BeautifulSoup. But Selenium s a good choice if target website has lot of java elements.

# %% [markdown]
# Q2. What's the difference between scraping images and scraping websites?
# Use an example to demonstrate your point.
#
# Answer: Image scraping is a subset of the web scraping technology. While web scraping deals with all forms of web data extraction, image scraping only focuses on the media side – images, videos, audio, and so on.
# An example of image scraping and web scraping is shown below using BeautifulSoap.

# %%
#web scraping
import requests
from bs4 import BeautifulSoup
URL = "https://ineuron.ai/"
r = requests.get(URL)
soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Affordable &amp; Competent Courses | iNeuron.ai
#   </title>
#   <meta content="Affordable &amp; Competent Courses | iNeuron.ai" name="title"/>
#   <meta content="Choose from the best in art expert-led courses now. Study any topic, anytime." name="description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://ineuron.ai/" property="og:url"/>
#   <meta content="Affordable &amp; Competent Courses | iNeuron.ai" property="og:title"/>
#   <meta content="Choose from the best in art expert-led courses now. Study any topic, anytime." property="og:description"/>
#   <meta content="./images/ineuron-main-thumbnail.png" property="og:image"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="https://ineuron.ai/" property="twitter:url"/>
# ...

# %%
#image scraping
import requests
from bs4 import BeautifulSoup
	
def getdata(url):
	r = requests.get(url)
	return r.text
	
htmldata = getdata("https://ineuron.ai/")
soup = BeautifulSoup(htmldata, 'html.parser')
for item in soup.find_all('img'):
	print(item['src'])
# Out:
# ./images/ineuron-logo.png
# ./images/down-arrow.svg
# ./images/hamburger.svg
# ./images/ineuron-logo.png
# ./images/section1-bg.svg
# ./images/hero-image-1.png
# ./images/play-button.svg
# ./images/hero-image-mobile.png
# ./images/affordable-illustration.png
# ./images/instructor-illustration.png
# ./images/lifetime-illustration.png
# ./images/affordable-illustration.png
# ./images/instructor-illustration.png
# ./images/lifetime-illustration.png
# /images/one-neuron-tick.png
# /images/one-neuron-tick.png
# /images/one-neuron-btn.png
# ./images/kids-img.png
# ./images/ineuron-vision.png
# ./images/ineuron-projects.png
# ./images/statistics.png
# ./images/curve.svg
# ./images/mentors/SudhanshuKumar.png
# ./images/curve.svg
# ./images/mentors/KrishNaik.png
# ./images/curve.svg
# ./images/mentors/SourangshuPaul.png
# ./images/curve.svg
# ./images/mentors/Sunny.png
# ./images/curve.svg
# ./images/mentors/Khushali.png
# ./images/curve.svg
# ./images/mentors/Jayant.png
# ./images/curve.svg
# ...

# %% [markdown]
# Q3. Explain how MongoDB indexes data.
#
# Answer: An index in MongoDB is similar to how indexes work in other database systems. Indexes are applied at the collection level, and can store the value of a specific field or set of fields, ordered by the value of the field.
#
# MongoDB uses multikey indexes to index the content stored in arrays. If we index a field that holds an array value, MongoDB creates separate index entries for every element of the array. These multikey indexes allow queries to select documents that contain arrays by matching on element or elements of the arrays.

# %% [markdown]
# Q4. What is the significance of the SET modifier?
#
# Answer: A set modifier modifies the selection of the preceding set identifier. If no set identifier is referenced, the current selection state is implicit.
#
# A set can be modified by an additional or a changed selection. Such a modification can be written in the set expression.
#
# The modifier consists of one or several field names, each followed by a selection that should be made on the field, all enclosed by < and >. For example: <Year={2007,+2008},Region={US}>. Field names and field values can be quoted as usual, e.g. <[Sales Region]={’West coast’, ’South America’}>.

# %% [markdown]
# Q5. Explain the MongoDB aggregation framework.
#
# Answer: The MongoDB Aggregation Framework is a way to query the data from MongoDB. It helps us to break the complex logics into a simple set of sequential operations. Just like a waterfall model, Output from one stage is fed as an input for the next stage until the desired result is achieved.
# Each stage of transformation during this process is termed as pipelines.
#
# Aggregation operations process multiple documents and return computed results. We can use aggregation operations to:
#
# - Group values from multiple documents together.
# - Perform operations on the grouped data to return a single result.
# - Analyze data changes over time.
#
# To perform aggregation operations, you can use:
#
# - Aggregation pipelines
# - Single purpose aggregation methods
# - Map-reduce functions

# %% [markdown]
# The aggregation framework in easy words it can be explained through stages mentioned below in the diagram :

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Refrences: I basically everytime refer to the MongoDB documentation regrading the framework and the menioned wordpress article.
#
# 1. https://mydbops.wordpress.com/2019/03/30/mongodb-aggregation-framework-an-overview/
#
# 2. https://docs.mongodb.com/manual/aggregation/
